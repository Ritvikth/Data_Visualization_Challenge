# %%
pip install python-dotenv
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install GeoViews
# Out:
# ...
#      -------------------------------------- 500.5/500.5 kB 6.3 MB/s eta 0:00:00
# ...
#      --------------------------------------- 10.9/10.9 MB 12.6 MB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#      ---------------------------------------- 4.8/4.8 MB 12.9 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 1.4/1.4 MB 12.4 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 46.5/46.5 kB ? eta 0:00:00
# ...
# Failed to build cartopy
# Note: you may need to restart the kernel to use updated packages.
#   error: subprocess-exited-with-error
#
# ...
#   exit code: 1
#
#   [279 lines of output]
# ...

# %%
conda install -c pyviz geoviews
# Out:
# Retrieving notices: ...working... done
# ...
# Solving environment: ...working... failed with initial frozen solve. Retrying with flexible solve.
# Solving environment: ...working... failed with repodata from current_repodata.json, will retry with next repodata source.
# ...
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\Ritvik\anaconda3
#
#   added / updated specs:
#     - geoviews
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     cartopy-0.18.0             |   py39h80a4efb_1         1.6 MB
#     cftime-1.5.1.1             |   py39h080aedc_0         148 KB
#     geopandas-base-0.9.0       |             py_1         919 KB
#     geos-3.8.0                 |       h33f27b4_0         905 KB
#     geoviews-1.9.5             |             py_0           4 KB  pyviz
# ...

# %%
pip install cartopy
# Out:
# ...
#   Using cached Cartopy-0.21.1.tar.gz (10.9 MB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#   Using cached shapely-2.0.0-cp39-cp39-win_amd64.whl (1.4 MB)
# ...
#   Using cached pyshp-2.3.1-py2.py3-none-any.whl (46 kB)
# ...
# Failed to build cartopy
# Note: you may need to restart the kernel to use updated packages.
#   error: subprocess-exited-with-error
#
# ...
#   exit code: 1
#
#   [279 lines of output]
#   <string>:90: UserWarning: Unable to determine GEOS version. Ensure you have 3.7.2 or later installed, or installation may fail.
#   running bdist_wheel
#   running build
#   running build_py
#   creating build
#   creating build\lib.win-amd64-cpython-39
# ...

# %%
# Import the required libraries and dependencies
import os
import pandas as pd
import matplotlib.pyplot as plt
import plotly.express as px
import hvplot.pandas
from pathlib import Path
from dotenv import load_dotenv
from panel.interact import interact

# %matplotlib inline

# %%
# Using the read_csv function and Path module, create a DataFrame 
file_path = Path("C:/Users/Ritvik/Documents/San Francisco Data Visualization/Resources/sfo_neighbourhoods_census_data.csv")
sfo_data_df = pd.read_csv(file_path, index_col="year")

# Review the first and last five rows of the DataFrame
sfo_data_df.head()
sfo_data_df.head(-5)
# Out:
#          neighbourhood  sale_price_sqr_foot  housing_units  gross_rent
# year
# 2010      Alamo Square           291.182945         372560        1239
# 2010        Anza Vista           267.932583         372560        1239
# 2010           Bayview           170.098665         372560        1239
# 2010  Buena Vista Park           347.394919         372560        1239
# 2010  Central Richmond           319.027623         372560        1239
# ...                ...                  ...            ...         ...
# 2016      Potrero Hill           707.651609         384242        4390
# 2016  Presidio Heights          1465.968586         384242        4390
# 2016      Russian Hill          1024.339877         384242        4390
# 2016   South of Market           531.136374         384242        4390
# 2016         Sunnyside           751.173709         384242        4390
#
# [392 rows x 4 columns]

# %%
# Create a numerical aggregation that groups the data by the year and then averages the results.
housing_units_by_year = sfo_data_df.groupby('year').mean()
housing_units_by_year = housing_units_by_year.drop(['sale_price_sqr_foot', 'gross_rent'], axis=1)

# Review the DataFrame
housing_units_by_year.head()
# Out:
#       housing_units
# year
# 2010       372560.0
# 2011       374507.0
# 2012       376454.0
# 2013       378401.0
# 2014       380348.0

# %%
# Create a visual aggregation explore the housing units by year
min = housing_units_by_year.min()['housing_units']
max = housing_units_by_year.max()['housing_units']

housing_units_by_year.plot.bar(ylim =(min-2000, max+2000),title="Housing Units in San Francisco from 2010 to 2016", figsize=(12,8))

plt.show()
plt.close('housing_units')

# %% [markdown]
# **Question:** What's the overall trend in housing units over the period that you're analyzing?
#
# **Answer:** The number of housing units from 2010 to 2016 have been gradually increasing.

# %%
# Create a numerical aggregation by grouping the data by year and averaging the results
sale_price_sqr_foot = pd.DataFrame(sfo_data_df.groupby(['year']).mean()['sale_price_sqr_foot'])
gross_rent = pd.DataFrame(sfo_data_df.groupby(['year']).mean()['gross_rent'])

# Review the resulting DataFrame
combined_price_rent
# Out:
#       sale_price_sqr_foot  gross_rent
# year
# 2010           369.344353      1239.0
# 2011           341.903429      1530.0
# 2012           399.389968      2324.0
# 2013           483.600304      2971.0
# 2014           556.277273      3528.0
# 2015           632.540352      3739.0
# 2016           697.643709      4390.0

# %% [markdown]
# **Question:** What is the lowest gross rent reported for the years included in the DataFrame?
#
# **Answer:** The lowest gross rent reported for the years included in the DataFrame is in 2010 with a gross rent of $1,239

# %%
# Filter out the housing_units column, creating a new DataFrame 
# Keep only sale_price_sqr_foot and gross_rent averages per year
combined_price_rent
# Out:
#       sale_price_sqr_foot  gross_rent
# year
# 2010           369.344353      1239.0
# 2011           341.903429      1530.0
# 2012           399.389968      2324.0
# 2013           483.600304      2971.0
# 2014           556.277273      3528.0
# 2015           632.540352      3739.0
# 2016           697.643709      4390.0

# %%
# Plot prices_square_foot_by_year. 
# Inclued labels for the x- and y-axes, and a title.
combined_price_rent.hvplot(
    title="Sale Price Per Square Foot and Average Gross Rent - 2010-2016 - San Francisco",
    xlabel="Year",
    ylabel="Gross Rent/Sale Price Per Square Foot",
)
# Out:
# :NdOverlay   [Variable]
#    :Curve   [year]   (value)

# %% [markdown]
# **Question:** Did any year experience a drop in the average sale price per square foot compared to the previous year?
#
# **Answer:** The year 2011 experienced a drop in average sale price per square food compared to the previous year

# %% [markdown]
# **Question:** If so, did the gross rent increase or decrease during that year?
#
# **Answer:** Gross rent increased that year but not as exponentially as the years following

# %%
# Group by year and neighbourhood and then create a new dataframe of the mean values
prices_by_year_by_neighbourhood = sfo_data_df.groupby([sfo_data_df.index, "neighbourhood"]).mean()

# Review the DataFrame
prices_by_year_by_neighbourhood.head()
prices_by_year_by_neighbourhood.head(-5)
# Out:
#                        sale_price_sqr_foot  housing_units  gross_rent
# year neighbourhood
# 2010 Alamo Square               291.182945       372560.0      1239.0
#      Anza Vista                 267.932583       372560.0      1239.0
#      Bayview                    170.098665       372560.0      1239.0
#      Buena Vista Park           347.394919       372560.0      1239.0
#      Central Richmond           319.027623       372560.0      1239.0
# ...                                    ...            ...         ...
# 2016 Potrero Hill               707.651609       384242.0      4390.0
#      Presidio Heights          1465.968586       384242.0      4390.0
#      Russian Hill              1024.339877       384242.0      4390.0
#      South of Market            531.136374       384242.0      4390.0
#      Sunnyside                  751.173709       384242.0      4390.0
#
# [392 rows x 3 columns]

# %%
# Filter out the housing_units
prices_by_year_by_neighbourhood = prices_by_year_by_neighbourhood.drop(['housing_units'], axis=1)

# Review the first and last five rows of the DataFrame
prices_by_year_by_neighbourhood.head()
prices_by_year_by_neighbourhood.head(-5)
# Out:
#                        sale_price_sqr_foot  gross_rent
# year neighbourhood
# 2010 Alamo Square               291.182945      1239.0
#      Anza Vista                 267.932583      1239.0
#      Bayview                    170.098665      1239.0
#      Buena Vista Park           347.394919      1239.0
#      Central Richmond           319.027623      1239.0
# ...                                    ...         ...
# 2016 Potrero Hill               707.651609      4390.0
#      Presidio Heights          1465.968586      4390.0
#      Russian Hill              1024.339877      4390.0
#      South of Market            531.136374      4390.0
#      Sunnyside                  751.173709      4390.0
#
# [392 rows x 2 columns]

# %%
# Use hvplot to create an interactive line plot of the average price per square foot
# The plot should have a dropdown selector for the neighbourhood
prices_by_year_by_neighbourhood.hvplot.line(
    title="Sale Price Per Square Foot and Average Gross Rent - 2010-2016 - By Neighborhood",
    xlabel="Year",
    ylabel="Gross Rent/Sale Price Per Square Foot",
    groupby='neighbourhood'
)
# Out:
# :DynamicMap   [neighbourhood]
#    :NdOverlay   [Variable]
#       :Curve   [year]   (value)

# %% [markdown]
# **Question:** For the Anza Vista neighbourhood, is the average sale price per square foot for 2016 more or less than the price that’s listed for 2012?
#
# **Answer:** The average sales price per square foot for 2016 for Anza Vista is less than the price that's listed for 2012

# %%
# Load neighbourhoods coordinates data
file_path2 = Path("C:/Users/Ritvik/Documents/San Francisco Data Visualization/Resources/neighbourhoods_coordinates.csv")
neighbourhood_locations_df = pd.read_csv(file_path2, index_col="Neighbourhood")

# Review the DataFrame
neighbourhood_locations_df.head()
# Out:
#                        Lat         Lon
# Neighbourhood
# Alamo Square     37.791012 -122.402100
# Anza Vista       37.779598 -122.443451
# Bayview          37.734670 -122.401060
# Bayview Heights  37.728740 -122.410980
# Bernal Heights   37.728630 -122.443050

# %%
# Calculate the mean values for each neighbourhood
all_neighbourhood_info_df = sfo_data_df.groupby("neighbourhood").mean()
all_neighbourhood_info_df.head()
# Out:
#                  sale_price_sqr_foot  housing_units   gross_rent
# neighbourhood
# Alamo Square              366.020712       378401.0  2817.285714
# Anza Vista                373.382198       379050.0  3031.833333
# Bayview                   204.588623       376454.0  2318.400000
# Bayview Heights           590.792839       382295.0  3739.000000
# Bernal Heights            576.746488       379374.5  3080.333333

# %%
# Using the Pandas `concat` function, join the 
# neighbourhood_locations_df and the all_neighbourhood_info_df DataFrame
# The axis of the concatenation is "columns".
# The concat function will automatially combine columns with
# identical information, while keeping the additional columns.
all_neighbourhoods_df = pd.concat(
    [neighbourhood_locations_df, all_neighbourhood_info_df], 
    axis="columns",
    sort=False
)

# Review the resulting DataFrame
display(all_neighbourhoods_df.head())
display(all_neighbourhoods_df.tail())
# Out:
#                        Lat         Lon  sale_price_sqr_foot  housing_units  \
# Alamo Square     37.791012 -122.402100           366.020712       378401.0
# Anza Vista       37.779598 -122.443451           373.382198       379050.0
# Bayview          37.734670 -122.401060           204.588623       376454.0
# Bayview Heights  37.728740 -122.410980           590.792839       382295.0
# Bernal Heights   37.728630 -122.443050                  NaN            NaN
#
#                   gross_rent
# Alamo Square     2817.285714
# Anza Vista       3031.833333
# Bayview          2318.400000
# Bayview Heights  3739.000000
# Bernal Heights           NaN
#                       Lat        Lon  sale_price_sqr_foot  housing_units  \
# Yerba Buena      37.79298 -122.39636           576.709848       377427.5
# Bernal Heights        NaN        NaN           576.746488       379374.5
# Downtown              NaN        NaN           391.434378       378401.0
# ...

# %%
# Call the dropna function to remove any neighbourhoods that do not have data
all_neighbourhoods_df = all_neighbourhoods_df.reset_index().dropna()

# Rename the "index" column as "Neighbourhood" for use in the Visualisation
all_neighbourhoods_df = all_neighbourhoods_df.rename(columns={"index": "Neighbourhood"})

# Review the resulting DataFrame
display(all_neighbourhoods_df.head())
display(all_neighbourhoods_df.tail())
# Out:
#       Neighbourhood        Lat         Lon  sale_price_sqr_foot  \
# 0      Alamo Square  37.791012 -122.402100           366.020712
# 1        Anza Vista  37.779598 -122.443451           373.382198
# 2           Bayview  37.734670 -122.401060           204.588623
# 3   Bayview Heights  37.728740 -122.410980           590.792839
# 5  Buena Vista Park  37.768160 -122.439330           452.680591
#
#    housing_units   gross_rent
# 0       378401.0  2817.285714
# 1       379050.0  3031.833333
# 2       376454.0  2318.400000
# 3       382295.0  3739.000000
# 5       378076.5  2698.833333
#          Neighbourhood       Lat         Lon  sale_price_sqr_foot  \
# 68         West Portal  37.74026 -122.463880           498.488485
# 69    Western Addition  37.79298 -122.435790           307.562201
# 70  Westwood Highlands  37.73470 -122.456854           533.703935
# 71       Westwood Park  37.73415 -122.457000           687.087575
# ...

# %%
# Create a plot to analyse neighbourhood info
all_neighbourhoods_df.hvplot.points(
    'Lon',
    'Lat',
    geo=True,
    size='sale_price_sqr_foot',
    color='gross_rent',
    titles='OSM',
    frame_width=700,
    frade_height=500
)
# Out:
# C:\Users\Ritvik\anaconda3\lib\site-packages\cartopy\crs.py:245: ShapelyDeprecationWarning: __len__ for multi-part geometries is deprecated and will be removed in Shapely 2.0. Check the length of the `geoms` property instead to get the  number of parts of a multi-part geometry.
#   if len(multi_line_string) > 1:
# C:\Users\Ritvik\anaconda3\lib\site-packages\cartopy\crs.py:297: ShapelyDeprecationWarning: Iteration over multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   for line in multi_line_string:
# C:\Users\Ritvik\anaconda3\lib\site-packages\cartopy\crs.py:364: ShapelyDeprecationWarning: __len__ for multi-part geometries is deprecated and will be removed in Shapely 2.0. Check the length of the `geoms` property instead to get the  number of parts of a multi-part geometry.
#   if len(p_mline) > 0:
# ...

# %% [markdown]
# **Question:** Which neighbourhood has the highest gross rent, and which has the highest sale price per square foot?
#
# **Answer:** The neighbourhood with the highest gross rent is Westwood Park with an average gross rent of $3,959.
#
# Union Square Capital has the highest sales price per unit square with an average of $904.

# %% [markdown]
# **Question:**  How does the trend in rental income growth compare to the trend in sales prices? Does this same trend hold true for all the neighbourhoods across San Francisco?
#
# **Answer:** Rental income and sales prices both have been growing overall in San Francisco, but this is not true for all neighbourhoods across San Francisco as some neighbourhoods had declining sales prices per square foot from 2014-2016

# %% [markdown]
# **Question:** What insights can you share with your company about the potential one-click, buy-and-rent strategy that they're pursuing? Do neighbourhoods exist that you would suggest for investment, and why?
#
# **Answer:** I would suggest with my company to keep pursuing the potential one-click, buy-and-rent strategy in San Francisco as the real estate industry there is doing very well which makes it a good testing ground for their service. There are certain neighbourhoods with low sales price per square feet in the year of 2016 and with high rental prices. These neighbourhoods would be the perfect testing grounds for the service as they would provide the highest ROI for investors in real estate within these areas.
